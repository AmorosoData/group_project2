# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# nuke data

nuke_file = pd.read_csv("data/cleaned_nuke_csv.csv")

nuke_df = pd.DataFrame(nuke_file) 

nuke_df.head(10)
# Out:
#    Unnamed: 0 country Code  Year  Quantity of Nuclear Weapons Country_Year  \
# 0           0   China  CHN  1960                            0   China 1960
# 1           1   China  CHN  1961                            0   China 1961
# 2           2   China  CHN  1962                            0   China 1962
# 3           3   China  CHN  1963                            0   China 1963
# 4           4   China  CHN  1964                            1   China 1964
# 5           5   China  CHN  1965                            5   China 1965
# 6           6   China  CHN  1966                           20   China 1966
# 7           7   China  CHN  1967                           25   China 1967
# 8           8   China  CHN  1968                           35   China 1968
# 9           9   China  CHN  1969                           50   China 1969
#
#    GDP (Current LCU)
# 0            1483.49
# 1            1089.96
# 2            1020.73
# 3            1098.53
# 4            1268.46
# ...

# %%
# drop unnamed column and rename code column
cleaned_nuke_df = nuke_df.drop('Unnamed: 0', 1)
cleaned_nuke_df = nuke_df.rename(columns={"Code":"country code"})
cleaned_nuke_df.head(10)
# Out:
#    Unnamed: 0 country country code  Year  Quantity of Nuclear Weapons  \
# 0           0   China          CHN  1960                            0
# 1           1   China          CHN  1961                            0
# 2           2   China          CHN  1962                            0
# 3           3   China          CHN  1963                            0
# 4           4   China          CHN  1964                            1
# 5           5   China          CHN  1965                            5
# 6           6   China          CHN  1966                           20
# 7           7   China          CHN  1967                           25
# 8           8   China          CHN  1968                           35
# 9           9   China          CHN  1969                           50
#
#   Country_Year  GDP (Current LCU)
# 0   China 1960            1483.49
# 1   China 1961            1089.96
# 2   China 1962            1020.73
# 3   China 1963            1098.53
# ...

# %%
#cleaned_nuke_df.loc[cleaned_nuke_df['country'] == 'Russia']
#cleaned_nuke_df.loc[cleaned_nuke_df['country'] == 'France']
#cleaned_nuke_df.loc[cleaned_nuke_df['country'] == 'India']
#cleaned_nuke_df.loc[cleaned_nuke_df['country'] == 'Israel']
#cleaned_nuke_df.loc[cleaned_nuke_df['country'] == 'Pakistan']
#cleaned_nuke_df.loc[cleaned_nuke_df['country'] == 'United Kingdom']
#cleaned_nuke_df.loc[cleaned_nuke_df['country'] == 'United States']
# Out:
#      Unnamed: 0        country country code  Year  \
# 356         356  United States          USA  1960
# 357         357  United States          USA  1961
# 358         358  United States          USA  1962
# 359         359  United States          USA  1963
# 360         360  United States          USA  1964
# 361         361  United States          USA  1965
# 362         362  United States          USA  1966
# 363         363  United States          USA  1967
# 364         364  United States          USA  1968
# 365         365  United States          USA  1969
# 366         366  United States          USA  1970
# 367         367  United States          USA  1971
# 368         368  United States          USA  1972
# 369         369  United States          USA  1973
# 370         370  United States          USA  1974
# 371         371  United States          USA  1975
# 372         372  United States          USA  1976
# 373         373  United States          USA  1977
# ...

# %%
# countries data
country_file = pd.read_csv("data/countries.csv")

country_df = pd.DataFrame(country_file) 

country_df.head(10)
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla
# 5      AL  41.153332  20.168331               Albania
# 6      AM  40.069099  45.038189               Armenia
# 7      AN  12.226079 -69.060087  Netherlands Antilles
# 8      AO -11.202692  17.873887                Angola
# 9      AQ -75.250973  -0.071389            Antarctica

# %%
# rename country column
updated_country_df = country_df.rename(columns={"country":"country code"})
updated_country_df
# Out:
#     country code   latitude  longitude                  name
# 0             AD  42.546245   1.601554               Andorra
# 1             AE  23.424076  53.847818  United Arab Emirates
# 2             AF  33.939110  67.709953           Afghanistan
# 3             AG  17.060816 -61.796428   Antigua and Barbuda
# 4             AI  18.220554 -63.068615              Anguilla
# ..           ...        ...        ...                   ...
# 240           YE  15.552727  48.516388                 Yemen
# 241           YT -12.827500  45.166244               Mayotte
# 242           ZA -30.559482  22.937506          South Africa
# 243           ZM -13.133897  27.849332                Zambia
# 244           ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]

# %%
#export to csv
updated_country_df.to_csv("data/updated_countries_10262020.csv", index=True)

# %%
# find China in updated_country_df , , , , russia, united kingdom, united states
updated_country_df.loc[updated_country_df['name'] == 'China']
# Out:
#    country code  latitude   longitude   name
# 45           CN  35.86166  104.195397  China

# %%
# find france in updated_country_df 
updated_country_df.loc[updated_country_df['name'] == 'France']
# Out:
#    country code   latitude  longitude    name
# 71           FR  46.227638   2.213749  France

# %%
# find india in updated_country_df 
updated_country_df.loc[updated_country_df['name'] == 'India']
# Out:
#     country code   latitude  longitude   name
# 102           IN  20.593684   78.96288  India

# %%
# find israel in updated_country_df 
updated_country_df.loc[updated_country_df['name'] == 'Israel']
# Out:
#     country code   latitude  longitude    name
# 100           IL  31.046051  34.851612  Israel

# %%
# find pakistan in updated_country_df 
updated_country_df.loc[updated_country_df['name'] == 'Pakistan']
# Out:
#     country code   latitude  longitude      name
# 174           PK  30.375321  69.345116  Pakistan

# %%
# find russia in updated_country_df 
updated_country_df.loc[updated_country_df['name'] == 'Russia']
# Out:
#     country code  latitude   longitude    name
# 187           RU  61.52401  105.318756  Russia

# %%
# find united kingdom in updated_country_df 
updated_country_df.loc[updated_country_df['name'] == 'United Kingdom']
# Out:
#    country code   latitude  longitude            name
# 73           GB  55.378051  -3.435973  United Kingdom

# %%
# find united states in updated_country_df 
updated_country_df.loc[updated_country_df['name'] == 'United States']
# Out:
#     country code  latitude  longitude           name
# 227           US  37.09024 -95.712891  United States

# %%
# replace country codes in nuke file to match country file
replace_values = {'CHN' : 'CN', 'FRA' : 'FR', 'IND' : 'IN', 'ISR' : 'IL', 'PAK' : 'PK', 'RUS' : 'RU', 'GBR' : 'GB', 'USA' : 'US'} 

cleaned_nuke_df = cleaned_nuke_df.replace({"country code": replace_values})
cleaned_nuke_df
# Out:
#      Unnamed: 0        country country code  Year  \
# 0             0          China           CN  1960
# 1             1          China           CN  1961
# 2             2          China           CN  1962
# 3             3          China           CN  1963
# 4             4          China           CN  1964
# ..          ...            ...          ...   ...
# 406         406  United States           US  2010
# 407         407  United States           US  2011
# 408         408  United States           US  2012
# 409         409  United States           US  2013
# 410         410  United States           US  2014
#
#      Quantity of Nuclear Weapons        Country_Year  GDP (Current LCU)
# 0                              0          China 1960            1483.49
# 1                              0          China 1961            1089.96
# 2                              0          China 1962            1020.73
# 3                              0          China 1963            1098.53
# ...

# %%
#export to csv
cleaned_nuke_df.to_csv("data/updated_nuke_10262020.csv", index=True)

# %%
# suicide data
suicide_file = pd.read_csv("data/suicide.csv")

suicide_df = pd.DataFrame(suicide_file) 

suicide_df.head(10)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
# 5  Albania  1987  female    75+ years            1       35600
# 6  Albania  1987  female  35-54 years            6      278800
# 7  Albania  1987  female  25-34 years            4      257200
# 8  Albania  1987    male  55-74 years            1      137500
# 9  Albania  1987  female   5-14 years            0      311000
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# ...
