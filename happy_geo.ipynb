# %%
import pandas as pd
import numpy as np
import pymongo
from pymongo import MongoClient

# %%
lat_lon_file = pd.read_csv("data/world_lat_lon.csv")

geo_df = pd.DataFrame(lat_lon_file)
geo_df.head()
# Out:
#   country_code   latitude  longitude               country usa_state_code  \
# 0           AD  42.546245   1.601554               Andorra             AK
# 1           AE  23.424076  53.847818  United Arab Emirates             AL
# 2           AF  33.939110  67.709953           Afghanistan             AR
# 3           AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4           AI  18.220554 -63.068615              Anguilla             CA
#
#    usa_state_latitude  usa_state_longitude   usa_state
# 0           63.588753          -154.493062      Alaska
# 1           32.318231           -86.902298     Alabama
# 2           35.201050           -91.831833    Arkansas
# 3           34.048928          -111.093731     Arizona
# 4           36.778261          -119.417932  California

# %%
geo_df = geo_df.rename(columns={"country":"Country", "latitude":"Latitude", "longitude":"Longitude"})
clean_geo_df = geo_df.drop(columns=["country_code","usa_state_code","usa_state_latitude","usa_state_longitude","usa_state"])
clean_geo_df = clean_geo_df[["Country","Latitude","Longitude"]]
clean_geo_df.head()
# Out:
#                 Country   Latitude  Longitude
# 0               Andorra  42.546245   1.601554
# 1  United Arab Emirates  23.424076  53.847818
# 2           Afghanistan  33.939110  67.709953
# 3   Antigua and Barbuda  17.060816 -61.796428
# 4              Anguilla  18.220554 -63.068615

# %%
happy_file = pd.read_csv("data/happy_2020.csv")
happy_df = pd.DataFrame(happy_file)
happy_df = happy_df.rename(columns={"Country name":"Country"})
happy_df = happy_df.drop(columns={"Regional indicator","Ladder score","Logged GDP per capita","Standard error of ladder score","upperwhisker","lowerwhisker","Ladder score in Dystopia","Explained by: Log GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy","Explained by: Freedom to make life choices","Explained by: Generosity","Explained by: Perceptions of corruption","Dystopia + residual"})
happy_country_df = happy_df.loc[happy_df["Country"].isin(["China","France","India","Israel","Pakistan","Russia","United Kingdom","United States"])]
happy_country_df
# Out:
#             Country  Social support  Healthy life expectancy  \
# 12   United Kingdom        0.936683                72.301605
# 13           Israel        0.913571                73.200256
# 17    United States        0.914219                68.299500
# 22           France        0.937104                73.801933
# 65         Pakistan        0.689062                58.253136
# 72           Russia        0.903151                64.100456
# 93            China        0.798761                69.289192
# 143           India        0.592201                60.215187
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 12                       0.834744    0.263732                   0.435916
# 13                       0.747581    0.102594                   0.780855
# 17                       0.842620    0.149892                   0.699715
# 22                       0.825468   -0.130642                   0.583521
# 65                       0.734834    0.044900                   0.745705
# 72                       0.729893   -0.151154                   0.864803
# 93                       0.898518   -0.181426                   0.753971
# 143                      0.881445    0.057552                   0.772043

# %%
happy_geo_merge_df = pd.merge(clean_geo_df,happy_country_df, on="Country", suffixes=("_geo","_happy"))
happy_geo_merge_df.head()
# Out:
#           Country   Latitude   Longitude  Social support  \
# 0           China  35.861660  104.195397        0.798761
# 1          France  46.227638    2.213749        0.937104
# 2  United Kingdom  55.378051   -3.435973        0.936683
# 3          Israel  31.046051   34.851612        0.913571
# 4           India  20.593684   78.962880        0.592201
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                69.289192                      0.898518   -0.181426
# 1                73.801933                      0.825468   -0.130642
# 2                72.301605                      0.834744    0.263732
# 3                73.200256                      0.747581    0.102594
# 4                60.215187                      0.881445    0.057552
#
#    Perceptions of corruption
# 0                   0.753971
# 1                   0.583521
# 2                   0.435916
# 3                   0.780855
# 4                   0.772043

# %%
happy_geo_merge_df.to_csv("data/happpy_geo", index=True)

# %% [markdown]
# # Database Setup

# %%
#Define connection link an instantiate client
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

#Define the database in Mongo
db = client.happydb

#Declare the business collection
happyGeo = db.happyGeo

# %%
#Instantiate for loop for populating business collection
for index, row in happy_geo_merge_df.iterrows():
    #Populate post dictionary with information to be inserted into business collection
    post = {
        "Country": str(row["Country"]),
        "Latitude": float(row["Latitude"]),
        "Longitude": float(row["Latitude"]),
        "Healthy life expectancy": float(row["Healthy life expectancy"]),
        "Freedom to make life choices": float(row["Freedom to make life choices"]),
        "Generosity": float(row["Generosity"]),
        "Perceptions of corruption": float(row["Perceptions of corruption"])

    }
    #Insert data into business collection, post{} by post{}
    happy_geo.insert_one(post)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-30-0bee69ffce2a> in <module>
#      13     }
#      14     #Insert data into business collection, post{} by post{}
# ---> 15     happy_geo.insert_one(post)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     696                          write_concern=write_concern,
#     697                          bypass_doc_val=bypass_document_validation,
# --> 698                          session=session),
#     699             write_concern.acknowledged)
#     700
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     610             return self._insert_one(
#     611                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 612                 bypass_doc_val, session)
#     613
#     614         ids = []
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     598
#     599         self.__database.client._retryable_write(
# --> 600             acknowledged, _insert_command, session)
#     601
#     602         if not isinstance(doc, RawBSONDocument):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1489     def _retryable_write(self, retryable, func, session):
#    1490         """Internal retryable write helper."""
# -> 1491         with self._tmp_session(session) as s:
#    1492             return self._retry_with_session(retryable, func, s, None)
#    1493
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1818             return
#    1819
# -> 1820         s = self._ensure_session(session)
#    1821         if s and close:
#    1822             with s:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1805             # Don't make implicit sessions causally consistent. Applications
#    1806             # should always opt-in.
# -> 1807             return self.__start_session(True, causal_consistency=False)
#    1808         except (ConfigurationError, InvalidOperation):
#    1809             # Sessions not supported, or multiple users authenticated.
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1758
#    1759         # Raises ConfigurationError if sessions are not supported.
# -> 1760         server_session = self._get_server_session()
#    1761         opts = client_session.SessionOptions(**kwargs)
#    1762         return client_session.ClientSession(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1791     def _get_server_session(self):
#    1792         """Internal: start or resume a _ServerSession."""
# -> 1793         return self._topology.get_server_session()
#    1794
#    1795     def _return_server_session(self, server_session, lock):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/topology.py in get_server_session(self)
#     475                             any_server_selector,
#     476                             self._settings.server_selection_timeout,
# --> 477                             None)
#     478                 elif not self._description.readable_servers:
#     479                     self._select_servers_loop(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     203             if timeout == 0 or now > end_time:
#     204                 raise ServerSelectionTimeoutError(
# --> 205                     self._error_message(selector))
#     206
#     207             self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %%
happy_geo_merge_df.to_json("data/happy_json.json")
